# %% [markdown]
# # Chapter2

# %%
# %run ./Chapter02/minivggnet_flowers17.py --dataset ./datasets/flowers17/images
# Out:
# [INFO] loading images...
# [INFO] processed 500/1360
# [INFO] processed 1000/1360
# [INFO] compiling model...
# [INFO] training network...
# Train on 1020 samples, validate on 340 samples
# Epoch 1/10
#  384/1020 [==========>...................] - ETA: 2:41 - loss: 3.8730 - acc: 0.1432

# %%
# %matplotlib inline
# plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, epochs), H.history["loss"], label="train_loss")
plt.plot(np.arange(0, epochs), H.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, epochs), H.history["acc"], label="train_acc")
plt.plot(np.arange(0, epochs), H.history["val_acc"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()

# %%
# %run ./Chapter02/minivggnet_flowers17_data_aug.py --dataset ./datasets/flowers17/images
# Out:
# [INFO] loading images...
# [INFO] processed 500/1360
# [INFO] processed 1000/1360
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/10
# 31/31 [==============================] - 205s 7s/step - loss: 3.3243 - acc: 0.1996 - val_loss: 4.6026 - val_acc: 0.2559
# Epoch 2/10
# 31/31 [==============================] - 222s 7s/step - loss: 2.4425 - acc: 0.3330 - val_loss: 2.4313 - val_acc: 0.4559
# Epoch 3/10
# 31/31 [==============================] - 221s 7s/step - loss: 2.1850 - acc: 0.3875 - val_loss: 2.0001 - val_acc: 0.4471
# Epoch 4/10
# 31/31 [==============================] - 216s 7s/step - loss: 1.7917 - acc: 0.4582 - val_loss: 3.6455 - val_acc: 0.3588
# Epoch 5/10
# 31/31 [==============================] - 207s 7s/step - loss: 1.6641 - acc: 0.4758 - val_loss: 2.2451 - val_acc: 0.4500
# Epoch 6/10
# 31/31 [==============================] - 201s 6s/step - loss: 1.6547 - acc: 0.4913 - val_loss: 2.0212 - val_acc: 0.4529
# Epoch 7/10
# ...

# %% [markdown]
# # Chapter3

# %%
# %run  ./Chapter03/extract_features.py --dataset ./datasets/animals/images --output ./datasets/animals/hdf5/features.hdf5
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO] loading network...
# Extracting Features: 100% |#####################################| Time: 1:21:03

# %%
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# %run ./Chapter03/train_model.py --db ./datasets/animals/hdf5/features.hdf5 --model animals.cpickle
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# [INFO] tuning hyperparameters...

# %%
import h5py
p = "./datasets/animals/hdf5/features.hdf5"
db = h5py.File(p)
list(db.keys())
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# ['features', 'label_names', 'labels']

# %%
db["features"].shape
# Out:
# (3000, 25088)

# %%
db["labels"].shape
# Out:
# (3000,)

# %%
db["label_names"].shape
# Out:
# (3,)

# %%
from pyimagesearch.utils import ranked

# %% [markdown]
# # Chapter4

# %%
# %run ./Chapter05/inspect_model.py
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] loading network...
# [INFO] showing layers...
# [INFO] 0	InputLayer
# [INFO] 1	Conv2D
# [INFO] 2	Conv2D
# [INFO] 3	MaxPooling2D
# [INFO] 4	Conv2D
# [INFO] 5	Conv2D
# [INFO] 6	MaxPooling2D
# [INFO] 7	Conv2D
# [INFO] 8	Conv2D
# [INFO] 9	Conv2D
# [INFO] 10	MaxPooling2D
# [INFO] 11	Conv2D
# [INFO] 12	Conv2D
# [INFO] 13	Conv2D
# [INFO] 14	MaxPooling2D
# [INFO] 15	Conv2D
# [INFO] 16	Conv2D
# [INFO] 17	Conv2D
# [INFO] 18	MaxPooling2D
# [INFO] 19	Flatten
# [INFO] 20	Dense
# [INFO] 21	Dense
# [INFO] 22	Dense

# %%
# %run ./Chapter05/inspect_model.py --include-top -1
# Out:
# [INFO] loading network...
# [INFO] showing layers...
# [INFO] 0	InputLayer
# [INFO] 1	Conv2D
# [INFO] 2	Conv2D
# [INFO] 3	MaxPooling2D
# [INFO] 4	Conv2D
# [INFO] 5	Conv2D
# [INFO] 6	MaxPooling2D
# [INFO] 7	Conv2D
# [INFO] 8	Conv2D
# [INFO] 9	Conv2D
# [INFO] 10	MaxPooling2D
# [INFO] 11	Conv2D
# [INFO] 12	Conv2D
# [INFO] 13	Conv2D
# [INFO] 14	MaxPooling2D
# [INFO] 15	Conv2D
# [INFO] 16	Conv2D
# [INFO] 17	Conv2D
# [INFO] 18	MaxPooling2D

# %%
# %run ./Chapter05/finetune_flowers17.py --dataset ./datasets/flowers17/images --model flowers17.model
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO] processed 500/1360
# [INFO] processed 1000/1360
# [INFO] compiling model...
# [INFO] training head...
# Epoch 1/25

# %%
# %run ./Chapter06/train_models.py --output output --models models
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] training model 1/5
# [INFO] training model 2/5
# [INFO] training model 3/5
# [INFO] training model 4/5
# [INFO] training model 5/5
# WARNING:tensorflow:Variable *= will be deprecated. Use variable.assign_mul if you want assignment to the variable value or 'x = x * y' if you want a new python Tensor object.
# Epoch 1/40
# 482/781 [=================>............] - ETA: 14:34 - loss: 1.9205 - acc: 0.3668

# %%
# %run ./Chapter06/test_ensemble.py --models models
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] evaluating ensemble...
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\numpy\lib\function_base.py:1128: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# ...

# %%
from config import dogs_vs_cats_config as config
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-4af405de5e2a> in <module>()
# ----> 1 from config import dogs_vs_cats_config as config
#
# ImportError: No module named 'config'

# %%
# %run ./dogs_vs_cats/build_dogs_vs_cats.py
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Building Dataset:   0% |                                       | ETA:  --:--:--
# [INFO] building ./datasets/kaggle_dogs_vs_cats/hdf5/train.hdf5...
# Building Dataset: 100% |########################################| Time: 0:25:53
# [INFO] building ./datasets/kaggle_dogs_vs_cats/hdf5/val.hdf5...
# Building Dataset: 100% |########################################| Time: 0:02:24
# Building Dataset:   0% |                                       | ETA:  --:--:--
# [INFO] building ./datasets/kaggle_dogs_vs_cats/hdf5/test.hdf5...
# Building Dataset: 100% |########################################| Time: 0:03:14
# ...

# %%
IMAGES_PATH = "..\\datasets\\kaggle_dogs_vs_cats\\train\\"

# %%
from imutils import paths

# %%
trainPaths = list(paths.list_images(config.IMAGES_PATH))

# %%
trainPaths[0].split(os.path.sep)
# Out:
# ['./datasets/kaggle_dogs_vs_cats/train', 'cat.0.jpg']

# %%
trainPaths[0]
# Out:
# './datasets/kaggle_dogs_vs_cats/train\\cat.0.jpg'

# %%
# %run ./dogs_vs_cats/train_alexnet.py
# Out:
# [INFO] compiling model...
# Epoch 1/75

# %%
# %run ./dogs_vs_cats/crop_accuracy.py
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] loading model...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# F:\Machine-Learning\Books\Deep-Learning-For-Computer-Vision-With-Python\compute_vision_with_python-master\Practitioner-Bundle\dogs_vs_cats\crop_accuracy.py in <module>()
#      23 # load the pretrained network
#      24 print("[INFO] loading model...")
# ---> 25 model = load_model(config.MODEL_PATH)
#      26
#      27 # initialize the testing dataset generator, then make predictions on
#
# ...

# %%
# %run ./dogs_vs_cats/extract_features.py --dataset ./datasets/kaggle_dogs_vs_cats/train \
--output ./datasets/kaggle_dogs_vs_cats/hdf5/features.hdf5
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] loading images...
# [INFO] loading network...
# Extracting Features:   2% |                                    | ETA:  17:11:58

# %%
# %run ./Chapter11/googlenet_cifar10.py --output output \
--model output/minigooglenet_cifar10.hdf5
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# [INFO] loading CIFAR-10 data...
# [INFO] compiling model...
# [INFO] training network...
# Epoch 1/70
#  22/781 [..............................] - ETA: 3:46:05 - loss: 2.2743 - acc: 0.1911

# %%
# %run ./deepergooglenet/build_tiny_imagenet.py
# Out:
# Building Dataset:   0% |                                       | ETA:  --:--:--
# [INFO] building ./datasets/tiny-imagenet-200/hdf5/train.hdf5...
# Building Dataset:  38% |###############                         | ETA:  0:17:14

# %%
# %run ./deepergooglenet/train.py --checkpoints output/checkpoints
# Out:
# D:\Users\Administrator\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# F:\Machine-Learning\Books\Deep-Learning-For-Computer-Vision-With-Python\compute_vision_with_python-master\Practitioner-Bundle\deepergooglenet\train.py in <module>()
#       8 from pyimagesearch.preprocessing import SimplePreprocessor
#       9 from pyimagesearch.preprocessing import MeanPreprocessor
# ---> 10 from pyimagesearch.callbacks import EpochCheckpoint
#      11 from pyimagesearch.callbacks import TrainingMonitor
# ...

# %%
 # %run ./Chapter03/extract_features.py --dataset datasets/animals/images --output datasets/animals/hdf5/features.hdf5
# Out:
# [INFO] loading images...
# [INFO] loading network...
# Extracting Features:  20% |#######                              | ETA:  0:50:47
